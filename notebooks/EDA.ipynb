# %% [markdown]
# # Exploratory Data Analysis (EDA)
#
# This notebook covers the Exploratory Data Analysis (EDA) for the Coronary Artery Disease clinical datasets.
#
# ### Key Steps:
# 1. Clinical variables distributions.
# 2. Missing data analysis and KNN imputation profiles.
# 3. Class imbalances and correlations between indicators.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load sample clinical data
df = pd.read_csv('../data/sample_data.csv')
df.info()
